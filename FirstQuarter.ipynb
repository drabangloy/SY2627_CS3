# %% [markdown]
# <a href="https://colab.research.google.com/github/drabangloy/SY2627_CS3/blob/main/FirstQuarter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### First  Topic ##

# %%
"""
This is a comment
"""
def add_numbers(a,b):
  breakpoint()
  return a + b

def multiple_numbers(a,b): # comment
  return a * b

def greet_user(name):
  return f"Hello, {name}! Welcome to Google Colab."

def main():
  print(add_numbers(5,3))
  print(multiple_numbers(4,2))
  print(greet_user("John Michael"))

if __name__ == "__main__":
  main()
# Out:
#   File "/tmp/ipykernel_2787/1096371331.py", line 15
#     print(add_numbers(5,3)
#          ^
# SyntaxError: '(' was never closed

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define a simple function
def calculate_square(x):
    return x ** 2

# Run and print output
result = calculate_square(10)
print(f"The square of 10 is: {result}")
# Out:
# The square of 10 is: 100
